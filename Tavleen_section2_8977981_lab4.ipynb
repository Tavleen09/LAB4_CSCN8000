# %% [markdown]
# # Add your Name: Tavleen Kaur<br>
# # StudentID: 8977981<br>
# # Please submit the notebook and HTML version of your notebook to EConestoga Dropbox

# %% [markdown]
# # **Question 1 - Pandas** (12 marks)

# %% [markdown]
# - Using RegularSeasonCompactResults.csv
# - and Teams.csv

# %%
# Using RegularSeasonCompactResults.csv
# 1- Create a filter to show if there are any draw matches
# 2- Apply the filter to the dataframe
# 3- SHOW the dataframe length or count (4 marks)
## TODO: Your code should be here

#Import pandas library
import pandas as pd

#Load the CSV data into a dataframe
df_results = pd.read_csv('C:/Users/HP/Downloads/CSCN8000/LAB4_CSCN8000/data/RegularSeasonCompactResults.csv')

#Create a filter for draw matches
draw_filter = df_results['Wteam'] == 'N' 

#Apply the filter to the dataframe
draw_matches_df = df_results[draw_filter]

#Show the length or count of the filtered dataframe
print("Number of draw matches:", draw_matches_df.shape[0])
# Out:
# Number of draw matches: 0

# %%
# Using RegularSeasonCompactResults.csv
# 1- Create a filter showing the entries where the winningteamID= 1400- (last two digits of your id)
# 2- Create another filter for the season of 2013
# 3- Apply the filter to the dataframe
# 4- Show the resulted dataframe (4 marks)
# (Example: IF your id is 8000021, the winning team id = 1400-21= 1389)
# TODO: Your code should be here

#Create a filter showing the entries
winning_team_id = 1400 - int(str(81)[-2:]) 
winning_team_filter = (df_results['Wteam'] == winning_team_id)

#Create a filter for the season of 2013
season_filter = (df_results['Season'] == 2013)

#Apply the filters to the dataframe
filtered_df = df_results[winning_team_filter & season_filter]

#Show the resulted dataframe
print(filtered_df)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 124367    2013      13   1319      85   1413      82    A      0
# 124655    2013      19   1319      70   1144      62    N      0
# 124935    2013      26   1319      77   1358      60    H      0
# 125424    2013      42   1319      87   1286      80    H      0
# 126002    2013      59   1319      57   1170      50    H      0
# 126755    2013      75   1319      60   1226      55    A      0
# 126959    2013      80   1319      67   1294      65    H      0
# 127479    2013      91   1319      62   1170      61    A      0
# 127594    2013      94   1319      79   1340      72    H      0
# 128043    2013     103   1319      74   1315      72    A      1
# 128549    2013     115   1319      67   1226      58    H      0

# %%
# Using RegularSeasonCompactResults.csv & Teams.csv
# 1- Load and merge both dataframes
# 2- Where the merge is on WinningTeamId (RegularSeasonCompactResults) and TeamId (Teams.csv)
# 3- Name the dataframe: DFCombined
# 4- Show the top 3 rows (4 marks)
# TODO: Your code should be here

#Load the dataset
df_teams = pd.read_csv('C:/Users/HP/Downloads/CSCN8000/LAB4_CSCN8000/data/Teams.csv') 

# Merge the dataframes on WinningTeamId and TeamId
DFCombined = pd.merge(df_results, df_teams, left_on='Wteam', right_on='Team_Id', how='inner')

# Show the top 3 rows 
print(DFCombined.head(3))
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Team_Id Team_Name
# 0    1985      20   1228      81   1328      64    N      0     1228  Illinois
# 1    1985      25   1228      64   1226      44    N      0     1228  Illinois
# 2    1985      27   1228      75   1332      72    N      3     1228  Illinois

# %% [markdown]
# # **Question 2 - Visualizations**

# %% [markdown]
# ## **Part I**
#
# Using the following dataset: https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv choose the most convenient graph to show the following, each question in **one** graph, using the library of your choice:
# (18 Marks)

# %% [markdown]
# **1. The relationship between the penguin's bill length and bill depth for each species.** (5 marks)

# %%
## TODO: Check your attributes, make a graph using Matplotlib or Seaborn to show the relationship needed

#Importing python libraries
import seaborn as sns
import matplotlib.pyplot as plt

#Load the dataset
penguins_data = pd.read_csv('C:/Users/HP/Downloads/CSCN8000/LAB4_CSCN8000/data/penguins.csv')
penguins = pd.DataFrame(penguins_data)

# Create a scatter plot using seaborn
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', palette='dark')

#Set plot labels and titles
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Relationship between Penguin\'s Bill Length and Bill Depth for Each Species')

#Show thw plot
plt.show()

# %% [markdown]
#  **What do you observe from the graph?** (2 marks)

# %% [markdown]
# Your answer here:
#
# It is observed from the graph that:
#
# 1. The lengths and depths of adelaide penguins' bills often vary greatly.
# 2. Bill length and depth appear to be fairly constant in chinstrap penguins.
# 3. The bill lengths of Gentoo penguins vary greatly, although the bill depths vary less.

# %% [markdown]
# **Why did you choose this type of graph?** (2 marks)

# %% [markdown]
# Your answer here:
#
# Because a scatter plot may graphically represent correlations, make species comparison easier, identify outliers, and show data distribution, it is a good option for investigating and showing the link between the bill length and bill depth of each species of penguin.

# %% [markdown]
# **2. Suitable graph of the mean BMI (BMI not body_mass weight_in_kg/height(m2)) of female and male penguins. (Assume the height is the flipper length)**  (5 marks)

# %%
#Your answer here

# Calculate BMI (Body Mass Index)
penguins['bmi'] = penguins['body_mass_g'] / ((penguins['flipper_length_mm'] / 1000) ** 2)

# Create a bar plot using seaborn
sns.barplot(x='sex', y='bmi', data=penguins)

#Set plot labels and titles
plt.xlabel('Gender')
plt.ylabel('Mean BMI')
plt.title('Mean BMI of Female and Male Penguins')

#Show the plot
plt.show()

# %% [markdown]
#  **What do you observe from the graph?** (2 marks)

# %% [markdown]
# Your answer here:
#
# 1. Comparison of Mean BMI: The mean BMIs of the male and female penguins are readily visible. A difference in mean BMI between the sexes is shown if one bar is greater than the other.
# 2. Distribution of BMI: The graph lets you see the distribution of BMI within each group in addition to the variation in mean BMI.
# 3. Possible Outliers: Look for any unexpected points or outliers in the data.

# %% [markdown]
# **Why did you choose this type of graph?** (2 marks)

# %% [markdown]
# Your answer here:
#
# Several factors led to the selection of the bar graph. First of all, it makes it possible to compare male and female penguins in a categorical manner. The mean BMI values are easily visualised and compared. Bar graphs also work well for showing the central tendency, which is important to know when concentrating on the mean BMI. Bar graphs are easily interpreted by a wide range of users due to their accessibility and simplicity, which makes it easy to determine the average BMI values for each gender.

# %% [markdown]
# ## **Part II**
#
# You can find the csv file that contains the museum visitors data here: ./CSVs/museum_visitors.csv
# (8 marks)

# %% [markdown]
# Review the data by taking a look at a few of the rows.

# %%
# Your solution here

#Load the dataset
museum_data = pd.read_csv('C:/Users/HP/Downloads/CSCN8000/LAB4_CSCN8000/data/museum_visitors.csv')

#Review the data
print(museum_data.head())
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum
# 0  2014-01-01        24778              4486                     1581  \
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# 3                                  2824
# 4                                 10694

# %% [markdown]
# Convince the museum board
#
# The Firehouse Museum claims they ran an event in 2014 that brought an incredible number of visitors, and that they should get extra budget to run a similar event again.  The other museums think these types of events aren't that important, and budgets should be split purely based on recent visitors on an average day.
#
# To show the museum board how the event compared to regular traffic at each museum, create a suitable chart that shows how the number of visitors to each museum evolved over time.
# (4 marks)

# %%
#Your solution here
# Convert the 'Date' column to datetime format
museum_data['Date'] = pd.to_datetime(museum_data['Date'])

# Create a line chart to show the evolution of visitors over time for each museum
plt.figure(figsize=(12, 6))

# Iterate through each museum and plot the number of visitors over time
for museum in museum_data.columns[1:]:
    plt.plot(museum_data['Date'], museum_data[museum], label=museum)

# Highlight the year 2014 for emphasis on the event
plt.axvline(pd.to_datetime('2014-01-01'), color='red', linestyle='--', label='Event Year (2014)')

# Set plot title and labels
plt.title('Evolution of Museum Visitors Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Visitors')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# What did you observe from the graph? (2 marks)

# %% [markdown]
# Your answer here
#
# From the graph it is observed that:
# 1. Event Impact (2014): In 2014, there was a noticeable increase in the number of visitors to one or more museums.
# 2. Comparative Trends: The graphic makes it possible to see how visiting patterns vary throughout museums.
# 3. Long-term Patterns: Using the chart, one may determine any long-term trends or variations in museum attendance over time, which is helpful for planning a budget.

# %% [markdown]
# Why did you choose this type of graph? (2 marks)

# %% [markdown]
# You answer here
#
# The line chart was used because it works well for displaying time-series data, making it easier to compare different museums, and clearly communicating information about how visitor numbers have changed over time, particularly the year of interest.

# %% [markdown]
# ## **PART III**

# %% [markdown]
# Using the file in ./CSVs/gas_prices.csv <br>
# Use a suitable plot/graph that will show the relationship between the gas price for each country (vs others) over all years. (8 marks)

# %% [markdown]
# First, review the data by taking a look at a few of the rows.

# %%
# Your solution here

#Load the dataset
gasprices_data = pd.read_csv('C:/Users/HP/Downloads/CSCN8000/LAB4_CSCN8000/data/gas_prices.csv')

#Review the data
print(gasprices_data.head())
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00  \
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %% [markdown]
# Then Plot using the most suitable plot on your opinion (5 marks)

# %%
## Your solution here

# Plotting the gas prices for each country over all years
plt.figure(figsize=(12, 8))
sns.lineplot(x='Year', y='Australia', data=gasprices_data)
sns.lineplot(x='Year', y='Canada', data=gasprices_data)
sns.lineplot(x='Year', y='France', data=gasprices_data)
sns.lineplot(x='Year', y='Germany', data=gasprices_data)
sns.lineplot(x='Year', y='Italy', data=gasprices_data)
sns.lineplot(x='Year', y='Japan', data=gasprices_data)
sns.lineplot(x='Year', y='Mexico', data=gasprices_data)
sns.lineplot(x='Year', y='South Korea', data=gasprices_data)
sns.lineplot(x='Year', y='UK', data=gasprices_data)
sns.lineplot(x='Year', y='USA', data=gasprices_data)

#Set labels and title
plt.title('Gas Prices Over the Years for Each Country')
plt.xlabel('Year')
plt.ylabel('Gas Price')

#Show the plot
plt.show()

# %% [markdown]
# Is there anything interesting observed from the plot/graph? (1 mark)

# %% [markdown]
# Your answer here
#
# The x-axis in this line graphic indicates the years, and each nation is represented by a line. The lines give each country's petrol price fluctuations over time a visual representation that makes trend detection and comparison simple.
#
# 1. Trends Over Time: This graphic will demonstrate how each nation's petrol costs have changed over time.
# 2. Comparisons by Country: It is simple to identify nations that exhibit comparable patterns or persistently higher or lower pricing.
# 3. Outliers: Sudden increases or decreases in the price of petrol for a certain nation may be considered anomalies.
# 4. Cross-Country Comparisons: By comparing the lines graphically, you can see which nations have, on average, higher or lower petrol costs over the course of the year.

# %% [markdown]
# Why did you choose this type of graph? (2 marks)

# %% [markdown]
# You answer here
#
# Because a line plot effectively visualises temporal patterns and makes direct comparisons possible, I decided to use it to illustrate the link between petrol prices for each nation over the course of all years. When showing how a variable, like petrol prices, varies over a continuous period of time, line plots are a good choice since they make it possible to see patterns, fluctuations, and long-term trends. A clear and distinct visual depiction of how petrol prices have changed over the given time period is provided by the plot, where each line represents a nation.
